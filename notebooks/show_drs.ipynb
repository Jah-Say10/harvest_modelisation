# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
sys.path.append(str(project_root / "src"))

from utils import get_drs

print(get_drs.drs_districts)
# Out:
# {
#     "DRS Dakar": [
#         "Dakar Centre",
#         "Dakar Nord",
#         "Dakar Ouest",
#         "Dakar Sud",
#         "Diamniadio",
#         "Guediawaye",
#         "Keur Massar",
#         "Mbao",
#         "Pikine",
#         "Rufisque",
#         "Sangalkam",
#         "Yeumbeul"
#     ],
#     "DRS Diourbel": [
#         "Bambey",
#         "Diourbel",
#         "Mbacke",
#         "Touba"
#     ],
#     "DRS Fatick": [
#         "Diakhao",
#         "Dioffior",
#         "Fatick",
#         "Foundiougne",
#         "Gossas",
#         "Niakhar",
#         "Passy",
#         "Sokone"
#     ],
#     "DRS Kaffrine": [
#         "Birkelane",
#         "Kaffrine",
#         "Koungheul",
#         "Malem Hodar"
#     ],
#     "DRS Kaolack": [
#         "Guinguineo",
#         "Kaolack",
#         "Ndoffane",
#         "Nioro"
#     ],
#     "DRS Kedougou": [
#         "Kedougou",
#         "Salemata",
#         "Saraya"
#     ],
#     "DRS Kolda": [
#         "Kolda",
# ...
